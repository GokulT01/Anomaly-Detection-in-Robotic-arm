# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, RepeatVector, TimeDistributed, Dense
from tensorflow.keras.optimizers import Adam
import time
import warnings
warnings.filterwarnings("ignore")

# ---------- 1. Load and preprocess training & test data ----------
try:
    df_train = pd.read_csv('robot_data_cleaned_properly.csv')
    df_test = pd.read_csv('test_data.csv')
except Exception as e:
    print(f"Error loading data: {e}")
    raise

# Compute joint errors
for df in [df_train, df_test]:
    for j in range(1, 7):
        df[f'ROBOT_TARGET_JOINT_POSITIONS (J{j})'] = pd.to_numeric(df[f'ROBOT_TARGET_JOINT_POSITIONS (J{j})'], errors='coerce')
        df[f'ROBOT_ACTUAL_JOINT_POSITIONS (J{j})'] = pd.to_numeric(df[f'ROBOT_ACTUAL_JOINT_POSITIONS (J{j})'], errors='coerce')
        df[f'JOINT_ERROR_J{j}'] = abs(df[f'ROBOT_TARGET_JOINT_POSITIONS (J{j})'] - df[f'ROBOT_ACTUAL_JOINT_POSITIONS (J{j})'])

# ---------- 2. Preprocessing function ----------
def preprocess_features(df, joint_num):
    features = [
        f'JOINT_ERROR_J{joint_num}',
        f'ROBOT_TARGET_JOINT_VELOCITIES (J{joint_num})',
        f'ROBOT_ACTUAL_JOINT_VELOCITIES (J{joint_num})',
        f'ROBOT_TARGET_JOITN_CURRENT (J{joint_num})',
        f'ROBOT_ACTUAL_JOINT_CURRENT (J{joint_num})'
    ]
    data = df[features].copy()
    for col in features[1:]:
        data[col] = data[col].astype(str).str.replace('[', '', regex=False).str.replace(']', '', regex=False)
        data[col] = pd.to_numeric(data[col].str.strip(), errors='coerce')
    data = data.fillna(method='ffill')
    scaler = MinMaxScaler()
    scaled = scaler.fit_transform(data)
    return scaled, scaler

# ---------- 3. Autoencoder Trainers ----------
def train_autoencoder(model_type, X_train, seq_len):
    X_seq = np.array([X_train[i:i+seq_len] for i in range(len(X_train)-seq_len)])
    if model_type == 'LSTM':
        model = Sequential([
            LSTM(64, activation='relu', input_shape=(seq_len, X_train.shape[1]), return_sequences=False),
            RepeatVector(seq_len),
            LSTM(64, activation='relu', return_sequences=True),
            TimeDistributed(Dense(X_train.shape[1]))
        ])
    elif model_type == 'GRU':
        model = Sequential([
            GRU(64, activation='relu', input_shape=(seq_len, X_train.shape[1]), return_sequences=False),
            RepeatVector(seq_len),
            GRU(64, activation='relu', return_sequences=True),
            TimeDistributed(Dense(X_train.shape[1]))
        ])
    model.compile(optimizer=Adam(0.001), loss='mse')
    start_time = time.time()
    model.fit(X_seq, X_seq, epochs=10, batch_size=32, verbose=0)
    elapsed_time = time.time() - start_time
    return model, elapsed_time

# ---------- 4. Anomaly Detection Function ----------
def detect_anomalies(model, X_test, seq_len, df_test, joint_num, label='Original'):
    X_seq = np.array([X_test[i:i+seq_len] for i in range(len(X_test)-seq_len)])
    preds = model.predict(X_seq)
    err = np.mean(np.square(X_seq - preds), axis=(1,2))
    threshold = np.percentile(err, 99.9)
    anomalies = np.where(err > threshold)[0] + seq_len

    def group_indices(indices):
        indices = sorted(indices)
        groups = []
        if not indices:
            return groups
        start = end = indices[0]
        for idx in indices[1:]:
            if idx == end + 1:
                end = idx
            else:
                groups.append((start, end))
                start = end = idx
        groups.append((start, end))
        return groups

    grouped = group_indices(anomalies.tolist())
    print(f"\n{label} Detection – Joint {joint_num} Anomaly Intervals:")
    for start, end in grouped:
        values = df_test.iloc[start:end+1][f'JOINT_ERROR_J{joint_num}']
        print(f"  Interval {start}-{end}: Max error = {values.max():.5f}, Avg error = {values.mean():.5f}")

    plt.figure(figsize=(10,4))
    plt.hist(err, bins=100, alpha=0.7)
    plt.axvline(threshold, color='red', linestyle='--', label='Threshold')
    plt.title(f'Reconstruction Error Distribution - Joint {joint_num} ({label})')
    plt.xlabel("Reconstruction Error")
    plt.ylabel("Frequency")
    plt.legend()
    plt.grid(True)
    plt.show()

    plt.figure(figsize=(14,5))
    plt.plot(df_test[f'JOINT_ERROR_J{joint_num}'], label=f'Joint {joint_num} Error')
    for start, end in grouped:
        plt.axvspan(start, end, color='red', alpha=0.3)
    plt.title(f'Anomaly Detection on Joint {joint_num} ({label})')
    plt.xlabel('Index')
    plt.ylabel('Error')
    plt.legend()
    plt.grid(True)
    plt.show()

    return anomalies.tolist(), err, threshold

# ---------- 5. Summarize Anomalies ----------
def summarize_anomalies(model_name, anomaly_indices, reconstruction_errors, threshold, joint_num, elapsed_time):
    def group_indices(indices):
        indices = sorted(indices)
        groups = []
        if not indices:
            return groups
        start = end = indices[0]
        for idx in indices[1:]:
            if idx == end + 1:
                end = idx
            else:
                groups.append((start, end))
                start = end = idx
        groups.append((start, end))
        return groups

    groups = group_indices(anomaly_indices)
    num_intervals = len(groups)
    interval_lengths = [end - start + 1 for start, end in groups]

    if len(anomaly_indices) > 0:
        max_error = max([reconstruction_errors[i] for i in anomaly_indices if i < len(reconstruction_errors)])
        mean_error = np.mean([reconstruction_errors[i] for i in anomaly_indices if i < len(reconstruction_errors)])
    else:
        max_error = 0
        mean_error = 0

    return {
        "Model": model_name,
        "Joint": joint_num,
        "Anomaly Intervals": num_intervals,
        "Avg Interval Length": np.mean(interval_lengths) if interval_lengths else 0,
        "Max Interval Length": max(interval_lengths) if interval_lengths else 0,
        "Max Error in Anomalies": max_error,
        "Mean Error in Anomalies": mean_error,
        "Threshold Used": threshold,
        "Train Time (s)": elapsed_time
    }

# ---------- 6. Run model analysis on all joints for both LSTM and GRU ----------
seq_len = 50
all_summaries = []

for model_type in ['LSTM', 'GRU']:
    print(f"\n================= Running {model_type} Autoencoder =================")
    for joint in range(1, 7):
        print(f"\n🚀 Running {model_type} model on Joint {joint} (Before Injection)...")
        X_train, scaler = preprocess_features(df_train, joint)
        X_test, _ = preprocess_features(df_test, joint)
        model, elapsed = train_autoencoder(model_type, X_train, seq_len)
        anomalies, err, threshold = detect_anomalies(model, X_test, seq_len, df_test, joint, label='Original')
        summary = summarize_anomalies(model_type, anomalies, err, threshold, joint, elapsed)
        all_summaries.append(summary)

    if model_type == 'LSTM':
        print("\n🔧 Injecting synthetic anomaly into Joint 3 from index 10000 to 10010")
        df_test.loc[10000:10010, 'JOINT_ERROR_J3'] += 0.05

    print(f"\n🔁 Re-running {model_type} model on Joint 3 (After Injection)...")
    X_train, scaler = preprocess_features(df_train, 3)
    X_test, _ = preprocess_features(df_test, 3)
    model, elapsed = train_autoencoder(model_type, X_train, seq_len)
    anomalies, err, threshold = detect_anomalies(model, X_test, seq_len, df_test, 3, label='With Injection')
    summary = summarize_anomalies(model_type + " (Injected)", anomalies, err, threshold, 3, elapsed)
    all_summaries.append(summary)

# ---------- 7. Display Overall Comparison ----------
comparison_df = pd.DataFrame(all_summaries)
print("\n================= Overall Model Comparison Summary =================")
print(comparison_df)

# Aggregate comparison per model type (excluding Injected runs)
overall_stats = comparison_df[~comparison_df['Model'].str.contains("Injected")].groupby('Model').agg({
    'Anomaly Intervals': 'sum',
    'Avg Interval Length': 'mean',
    'Max Interval Length': 'max',
    'Max Error in Anomalies': 'mean',
    'Mean Error in Anomalies': 'mean',
    'Threshold Used': 'mean',
    'Train Time (s)': 'mean'
}).reset_index()

print("\n================= Aggregated Model Performance =================")
print(overall_stats)

# Visual comparison
plt.figure(figsize=(12, 6))
bar_width = 0.25
x = np.arange(len(overall_stats['Model']))

plt.bar(x - bar_width, overall_stats['Max Error in Anomalies'], width=bar_width, label='Max Error')
plt.bar(x, overall_stats['Mean Error in Anomalies'], width=bar_width, label='Mean Error')
plt.bar(x + bar_width, overall_stats['Train Time (s)'], width=bar_width, label='Avg Train Time (s)')

plt.xticks(x, overall_stats['Model'])
plt.ylabel('Metric Value')
plt.title('LSTM vs GRU - Error and Time Comparison (All Joints)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ================= Running LSTM Autoencoder =================
#
# 🚀 Running LSTM model on Joint 1 (Before Injection)...
# 805/805 ━━━━━━━━━━━━━━━━━━━━ 28s 32ms/step
#
# Original Detection – Joint 1 Anomaly Intervals:
#   Interval 13705-13712: Max error = 0.00824, Avg error = 0.00590
#   Interval 13869-13869: Max error = 0.02684, Avg error = 0.02684
#   Interval 16529-16531: Max error = 0.00883, Avg error = 0.00489
#   Interval 16534-16537: Max error = 0.01544, Avg error = 0.00932
#   Interval 18157-18160: Max error = 0.03964, Avg error = 0.03088
#   Interval 18164-18164: Max error = 0.02646, Avg error = 0.02646
#   Interval 18167-18167: Max error = 0.01701, Avg error = 0.01701
#   Interval 18176-18176: Max error = 0.01496, Avg error = 0.01496
#   Interval 18178-18179: Max error = 0.01067, Avg error = 0.00709
#   Interval 25223-25223: Max error = 0.00137, Avg error = 0.00137
# 🚀 Running LSTM model on Joint 2 (Before Injection)...
# 805/805 ━━━━━━━━━━━━━━━━━━━━ 27s 31ms/step
#
# Original Detection – Joint 2 Anomaly Intervals:
#   Interval 1852-1860: Max error = 0.01127, Avg error = 0.00436
#   Interval 7382-7384: Max error = 0.01742, Avg error = 0.01227
#   Interval 16823-16823: Max error = 0.00348, Avg error = 0.00348
#   Interval 17691-17703: Max error = 0.01315, Avg error = 0.00707
# 🚀 Running LSTM model on Joint 3 (Before Injection)...
# 805/805 ━━━━━━━━━━━━━━━━━━━━ 28s 32ms/step
#
# Original Detection – Joint 3 Anomaly Intervals:
#   Interval 3749-3762: Max error = 0.00611, Avg error = 0.00353
#   Interval 11779-11786: Max error = 0.00756, Avg error = 0.00356
#   Interval 14901-14904: Max error = 0.00383, Avg error = 0.00163
# 🚀 Running LSTM model on Joint 4 (Before Injection)...
# 805/805 ━━━━━━━━━━━━━━━━━━━━ 29s 34ms/step
#
# Original Detection – Joint 4 Anomaly Intervals:
#   Interval 2719-2720: Max error = 0.01514, Avg error = 0.01424
#   Interval 2722-2729: Max error = 0.01995, Avg error = 0.01551
#   Interval 2733-2737: Max error = 0.01664, Avg error = 0.01501
#   Interval 10742-10752: Max error = 0.01156, Avg error = 0.00403
# 🚀 Running LSTM model on Joint 5 (Before Injection)...
# 805/805 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step
#
# Original Detection – Joint 5 Anomaly Intervals:
#   Interval 3929-3930: Max error = 0.01716, Avg error = 0.01613
#   Interval 3932-3932: Max error = 0.01306, Avg error = 0.01306
#   Interval 18895-18912: Max error = 0.01784, Avg error = 0.01423
#   Interval 23637-23637: Max error = 0.01163, Avg error = 0.01163
#   Interval 25175-25176: Max error = 0.01098, Avg error = 0.00825
#   Interval 25179-25180: Max error = 0.01235, Avg error = 0.01132
# 🚀 Running LSTM model on Joint 6 (Before Injection)...
# 805/805 ━━━━━━━━━━━━━━━━━━━━ 33s 38ms/step
#
# Original Detection – Joint 6 Anomaly Intervals:
#   Interval 2379-2390: Max error = 0.00273, Avg error = 0.00154
#   Interval 16686-16690: Max error = 0.00549, Avg error = 0.00453
#   Interval 19829-19829: Max error = 0.00481, Avg error = 0.00481
#   Interval 22887-22894: Max error = 0.00816, Avg error = 0.00439
# 🔧 Injecting synthetic anomaly into Joint 3 from index 10000 to 10010
#
# 🔁 Re-running LSTM model on Joint 3 (After Injection)...
# 805/805 ━━━━━━━━━━━━━━━━━━━━ 33s 39ms/step
#
# With Injection Detection – Joint 3 Anomaly Intervals:
#   Interval 10006-10011: Max error = 0.05533, Avg error = 0.04510
#   Interval 10016-10020: Max error = 0.00388, Avg error = 0.00217
#   Interval 10023-10037: Max error = 0.00948, Avg error = 0.00388
# ================= Running GRU Autoencoder =================
#
# 🚀 Running GRU model on Joint 1 (Before Injection)...
# 805/805 ━━━━━━━━━━━━━━━━━━━━ 30s 35ms/step
#
# Original Detection – Joint 1 Anomaly Intervals:
#   Interval 1389-1389: Max error = 0.02171, Avg error = 0.02171
#   Interval 9791-9792: Max error = 0.00544, Avg error = 0.00406
#   Interval 10551-10553: Max error = 0.00635, Avg error = 0.00484
#   Interval 12554-12554: Max error = 0.01902, Avg error = 0.01902
#   Interval 16360-16360: Max error = 0.01987, Avg error = 0.01987
#   Interval 16730-16743: Max error = 0.00476, Avg error = 0.00307
#   Interval 17496-17497: Max error = 0.00816, Avg error = 0.00739
#   Interval 21124-21125: Max error = 0.00374, Avg error = 0.00343
# 🚀 Running GRU model on Joint 2 (Before Injection)...
# 805/805 ━━━━━━━━━━━━━━━━━━━━ 32s 37ms/step
#
# Original Detection – Joint 2 Anomaly Intervals:
#   Interval 5188-5189: Max error = 0.02989, Avg error = 0.02934
#   Interval 5208-5208: Max error = 0.00519, Avg error = 0.00519
#   Interval 5212-5212: Max error = 0.00143, Avg error = 0.00143
#   Interval 7382-7393: Max error = 0.01819, Avg error = 0.01194
#   Interval 16079-16081: Max error = 0.00737, Avg error = 0.00552
#   Interval 19212-19213: Max error = 0.01638, Avg error = 0.01548
#   Interval 19216-19220: Max error = 0.01369, Avg error = 0.00828
# 🚀 Running GRU model on Joint 3 (Before Injection)...
# 805/805 ━━━━━━━━━━━━━━━━━━━━ 31s 36ms/step
#
# Original Detection – Joint 3 Anomaly Intervals:
#   Interval 10022-10047: Max error = 0.01134, Avg error = 0.00481
# 🚀 Running GRU model on Joint 4 (Before Injection)...
# 805/805 ━━━━━━━━━━━━━━━━━━━━ 28s 33ms/step
#
# Original Detection – Joint 4 Anomaly Intervals:
#   Interval 3665-3666: Max error = 0.00175, Avg error = 0.00153
#   Interval 10741-10754: Max error = 0.01156, Avg error = 0.00472
#   Interval 11653-11659: Max error = 0.02302, Avg error = 0.01593
#   Interval 11681-11682: Max error = 0.00502, Avg error = 0.00470
#   Interval 11684-11684: Max error = 0.00851, Avg error = 0.00851
# 🚀 Running GRU model on Joint 5 (Before Injection)...
# 805/805 ━━━━━━━━━━━━━━━━━━━━ 28s 33ms/step
#
# Original Detection – Joint 5 Anomaly Intervals:
#   Interval 18895-18914: Max error = 0.01784, Avg error = 0.01415
#   Interval 18916-18916: Max error = 0.01098, Avg error = 0.01098
#   Interval 25174-25178: Max error = 0.01306, Avg error = 0.01031
# 🚀 Running GRU model on Joint 6 (Before Injection)...
# 805/805 ━━━━━━━━━━━━━━━━━━━━ 27s 31ms/step
#
# Original Detection – Joint 6 Anomaly Intervals:
#   Interval 2378-2396: Max error = 0.00273, Avg error = 0.00130
#   Interval 7930-7934: Max error = 0.00413, Avg error = 0.00138
#   Interval 16236-16236: Max error = 0.00481, Avg error = 0.00481
#   Interval 22900-22900: Max error = 0.00337, Avg error = 0.00337
# 🔁 Re-running GRU model on Joint 3 (After Injection)...
# 805/805 ━━━━━━━━━━━━━━━━━━━━ 31s 35ms/step
#
# With Injection Detection – Joint 3 Anomaly Intervals:
#   Interval 10017-10042: Max error = 0.00948, Avg error = 0.00364
# ================= Overall Model Comparison Summary =================
#               Model  Joint  Anomaly Intervals  Avg Interval Length  \
# 0              LSTM      1                 10             2.600000
# 1              LSTM      2                  4             6.500000
# 2              LSTM      3                  3             8.666667
# 3              LSTM      4                  4             6.500000
# 4              LSTM      5                  6             4.333333
# 5              LSTM      6                  4             6.500000
# 6   LSTM (Injected)      3                  3             8.666667
# 7               GRU      1                  8             3.250000
# 8               GRU      2                  7             3.714286
# 9               GRU      3                  1            26.000000
# 10              GRU      4                  5             5.200000
# 11              GRU      5                  3             8.666667
# 12              GRU      6                  4             6.500000
# 13   GRU (Injected)      3                  1            26.000000
#
#     Max Interval Length  Max Error in Anomalies  Mean Error in Anomalies  \
# 0                     8                0.002542                 0.001370
# 1                    13                0.002164                 0.001492
# 2                    14                0.005524                 0.002653
# 3                    11                0.007925                 0.006667
# 4                    18                0.002388                 0.001032
# 5                    12                0.009711                 0.006570
# 6                    15                0.007784                 0.002479
# 7                    14                0.000884                 0.000523
# 8                    12                0.002187                 0.001705
# 9                    26                0.001052                 0.000978
# 10                   14                0.005234                 0.004376
# 11                   20                0.001838                 0.000853
# 12                   19                0.007690                 0.004542
# 13                   26                0.001043                 0.000994
#
#     Threshold Used  Train Time (s)
# 0         0.004725     1834.807445
# 1         0.010215     1797.157588
# 2         0.014196     1809.503556
# 3         0.012341     1906.942367
# 4         0.012510     2235.493205
# 5         0.015423     2177.312859
# 6         0.014322     2241.345785
# 7         0.007294     2336.421185
# 8         0.006521     2406.095048
# 9         0.014122     2388.790953
# 10        0.008246     2370.738497
# 11        0.011266     2185.398463
# 12        0.010890     2213.034602
# 13        0.017424     2260.490336
#
# ================= Aggregated Model Performance =================
#   Model  Anomaly Intervals  Avg Interval Length  Max Interval Length  \
# 0   GRU                 28             8.888492                   26
# 1  LSTM                 31             5.850000                   18
#
#    Max Error in Anomalies  Mean Error in Anomalies  Threshold Used  \
# 0                0.003148                 0.002163        0.009723
# 1                0.005042                 0.003297        0.011569
#
#    Train Time (s)
# 0     2316.746458
# 1     1960.202837

# %%
def evaluate_joint_health(df, joint_num):
    error_col = f'JOINT_ERROR_J{joint_num}'
    errors = df[error_col].dropna()

    max_err = errors.max()
    avg_err = errors.mean()

    if max_err >= 0.45:
        return f"Joint {joint_num}: CRITICAL – max error {max_err:.5f} exceeds 0.45 threshold"
    elif max_err >= 0.1:
        return f"Joint {joint_num}: WARNING – max error {max_err:.5f} exceeds 0.1 threshold"
    elif avg_err >= 0.01:
        return f"Joint {joint_num}: MONITOR – avg error {avg_err:.5f} suggests potential early warning"
    else:
        return f"Joint {joint_num}: GOOD – operating within safe error bounds"

print("\n================= FINAL JOINT HEALTH STATUS =================")
for j in range(1, 7):
    print(evaluate_joint_health(df_test, j))
# Out:
# ================= FINAL JOINT HEALTH STATUS =================
# Joint 1: GOOD – operating within safe error bounds
# Joint 2: GOOD – operating within safe error bounds
# Joint 3: GOOD – operating within safe error bounds
# Joint 4: GOOD – operating within safe error bounds
# Joint 5: GOOD – operating within safe error bounds
# Joint 6: GOOD – operating within safe error bounds
